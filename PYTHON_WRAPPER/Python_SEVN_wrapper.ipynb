# %% [markdown]
# #  Python Wrapper
#
# This code allows us to run SEVN code from a  simple pythonic interface. The wrapper feeds in all the variables that are used in order to run the sevn.x and sevnB.x files for the single stellar evolution and the binary stellar evolution respectively as well setup and compile the underlying SEVN code for the first time users.

# %% [markdown]
# ## Python Wrapper: Under the hood (not usually viewed by user)

# %% [markdown]
# ### Set the default model parameters
# For conistency the input varible names used in the Python Wrapper have the same names as that used already in  runscripts, these are translated to the names that the sevn.x and sevnB.x files expect with a python dictionary.

# %%
#### Dictionary mapping between runscript/python names to params in sevnB.x
mappings = {'NTHREADS': 'nthreads','LISTBIN': 'list','IBMODE': 'ibmode','TABLES': 'tables',
 'TABLESHE': 'tables_HE','OMODE': 'omode','OUTPATH': 'o','WINDSMODE': 'wmode','TIDES': 'tmode',
 'GWMODE': 'gwmode','RLMODE': 'rlmode','CIRCMODE': 'circmode','CEMODE': 'cemode','MIXING': 'mixmode','COLLMODE': 'collmode',
 'HARDMODE': 'hardmode','SNORBCHANGE': 'kmode','SNKICKS': 'sn_kicks','SNPISN': 'sn_pairinstability','SNNML': 'sn_neutrinomaloss','SUPERNOVA': 'snmode',
 'BHXSPIN': 'xspinmode','MAXWSDXSPIN': 'xspin_sigma_maxwell','BAVERAXSPIN': 'xspin_bavera','GWTSHOLD': 'gw_tshold','GWONLYBCO': 'gw_onlybco','JTEMAX': 'jtrack_h_err_rel_max',
 'JTMAXDM': 'jtrack_max_dm_factor','JTMAXITER': 'jtrack_max_iteration','JTMINDM': 'jtrack_min_dm_factor','JTDMTSHOLD': 'jtrack_tshold_dm_rel','EDDF': 'eddington_factor','RLOEPSNOVA': 'rlo_eps_nova',
 'RLOMACCR': 'rlo_f_mass_accreted','RLOGAM': 'rlo_gamma_angmom','RLOSTABILITY': 'rlo_stability','RLONTMAX': 'rlo_max_nuclearmt','RLOSMTMS': 'rlo_mtstable_ms','RLOCOLLISION': 'rlo_enable_collision',
 'MCHANDRA': 'sn_Mchandra','SNLOWECSN': 'sn_co_lower_ecsn','SNLOW': 'sn_co_lower_sn','SNLOWECSNHE': 'sn_co_lower_ecsn_pureHe','SNLOWHE': 'sn_co_lower_sn_pureHe','NSMAX': 'sn_max_ns_mass',
 'SNMINVKICK': 'sn_min_vkick','SNVKICKSTD': 'sn_kick_velocity_stdev','NSMASSMEAN': 'sn_Mremnant_average_NS','NSMASSSTD': 'sn_Mremnant_std_NS','WALPHA': 'w_alpha','WBETA': 'w_beta',
 'LITPHASES': 'io_literal_phases','LOGLEVEL': 'log_level','NCHUNK': 'ev_Nchunk','MAXREP': 'ev_max_repetitions','TEND': 'tf','TSTART': 'tini',
 'RSEED': 'rseed','SQHE': 'rlo_QHE','TABCONV': 'tabuse_envconv','TABXSUP': 'tabuse_Xsup','TABINERTIA': 'tabuse_inertia','INERTIAMODE': 'inertiamode',
 'TABRCO': 'tabuse_rhe','CEALPHA': 'ce_alpha','CEKCE': 'ce_kce','CEKNCE': 'ce_knce','CELAM': 'star_lambda','CELAMHE': 'star_lambda_pureHe',
 'CELAMFTH': 'star_lambda_fth','WRTS': 'star_tshold_WR_envelope','NSMAGTSCALE': 'ns_magnetic_tscale','NSMAGMSCALE': 'ns_magnetic_mscale','SNC25TS': 'sn_compact_csi25_tshold','SNCOMPFB': 'sn_compact_fallback',
 'NAKEDTS': 'ev_naked_tshold','Z ': 'Z','LOGFILE': 'io_logfile','INITERRSTOP': 'initerror_stop','SMAXCO': 'ev_set_maxCO','SMINHE': 'ev_set_minHE',
 'THGHURLEY': 'use_thg_hurley','TSMAXVAR': 'ts_maximum_variation','TSMIN': 'ts_min_dt','TSMAX': 'ts_max_dt','TSSPIN': 'ts_check_spin','TSSPINBIN': 'ts_check_spin_bin',
 'TSNSSPIN': 'ts_check_NSspin','OPTIMISTIC': 'optimistic_scenario_hg','HARDRHOC': 'hard_rhoc','HARDSIGMA': 'hard_sigma','HARDXI': 'hard_xi','HARDKAPPA': 'hard_kappa','HARDMASS': 'hard_mass_average',
 'INTW': 'ev_setwM','INTWLOG': 'ev_setwM_log','INTWPHASE': 'ev_setwM_tphase','CKSTALLING': 'check_stalling', 'DTOUT' : 'dtout'}

path_error = "Please set path to the SEVN folder with set_path('path_to_SEVN')"
py_to_input_dict = {'True' : 'true', 'False' : 'false'}

# %% [markdown]
# ### Python function Definitions:  Set Up Tools

# %% [markdown]
# This a few ease of use tools to check the setup in users SEVN directory, and add the correct lines if needed and also comiple the c++ code.

# %%
## imports minimal better 
import os
from datetime import datetime

def set_path(install_path, exe_path = None): 
    #Maybe write somthing that keeps track of the installation
    global SEVN
    SEVN = install_path

#SET UP TOOLS--------------------------------
def add_SEVN_path_to_file(file_path): # automatically adds the users SEVN path to given file 
    if 'SEVN' in globals():
        #read 
        f = open(file_path, "r")
        replaced_content = ""
        catch_str = 'SEVN="<Insert absolute SEVNpath>"'
        out_str = 'SEVN="'+SEVN + '" #Complete path to the SEVN folder'
        for line in f:
            if catch_str in line:
                replaced_content += out_str + "\n"
            else:
                replaced_content += line         
        f.close()
        out_f = open(file_path, "w")
        out_f.write(replaced_content)
        out_f.close()

def sevn_compile():
    if 'SEVN' not in globals():print(path_error)
    else: #os.system(os.path.join(SEVN, "compile.sh"))
        from subprocess import run as sp_run# more compatable than capture_output
        sp=sp_run(os.path.join(SEVN, "compile.sh"), shell=True, cwd=SEVN)
    
def check_compile():
    # only runs if not built
    if 'SEVN' in globals() and not os.path.exists(os.path.join(SEVN, 'build')):
        add_SEVN_path_to_file(os.path.join(SEVN, "compile.sh"))
        add_SEVN_path_to_file(os.path.join(SEVN, "run_scripts", "run.sh"))
        add_SEVN_path_to_file(os.path.join(SEVN, "run_scripts", "run_sse.sh"))
        sevn_compile() 
    if 'SEVN' in globals() and os.path.exists(os.path.join(SEVN, 'build')):
        print("SEVN already compiled")
    if 'SEVN' not in globals():print(path_error)

# %% [markdown]
# ### Python function Definitions:  Class Functions

# %% [markdown]
# #### Functions called inside the classes

# %%
#Convert between the Standard Python varible values and the c++ input
def var_format(var):
    var=str(var)
    if var in py_to_input_dict:
        var = py_to_input_dict[var]
    return var

# Generate output folder and copy in the launch command and binary ran
def update_outdir(self, launch_time):
    ## create the outpath folder
    if not os.path.isdir(self.output.OUTPATH):
        os.mkdir(self.output.OUTPATH)
    source = open(self.EXE, "rb")
    file_name=os.path.basename(self.EXE)
    dest = open(os.path.join(self.output.OUTPATH,file_name), "wb")
    dest.write(source.read())
    source.close()
    dest.close()
    
    # save output comand
    text_file = open(os.path.join(self.output.OUTPATH,"launch_line.txt"), "w")
    text_file.write("[SEVN launch string]:" +self.output.RUNCMD)
    text_file.close()
    print("Directory '%s' created" %self.output.OUTPATH)

# %% [markdown]
# #### Class methods

# %%
#get the launch command list for a set of paramters 
def gen_cmd_list(self):
    if type(self) is dict:param_dict = self
    else: param_dict = vars(self)
    cmd_dict= {key:str(mappings[key]) + " "+ var_format(param_dict[key]) for key in param_dict if key in mappings}
    
    #Exceptions
    # Check SCOL, BCOL and NAMEPREX, if they are empty do not add it
    if hasattr(self, "SCOL"):#all in same param set
        if isinstance(self.SCOL, str) and self.SCOL: cmd_dict["scol"] = 'scol ' + self.SCOL
        if isinstance(self.BCOL, str) and self.BCOL: cmd_dict["bcol"] = 'bcol ' + self.BCOL
        if isinstance(self.NAMEPREX, str) and self.NAMEPREX !="": cmd_dict["name_prefix"] ="name_prefix " + self.NAMEPREX
    
    #Run script uses 'TABRCO' for'tabuse_rhe' and 'tabuse_rco'
    if hasattr(self, "TABRCO"):  cmd_dict["TABRCO"] = cmd_dict["TABRCO"] +  ' -tabuse_rco ' + var_format(self.TABRCO)
    # create the output cmd
    cmd_list= [str(cmd_dict[key]) for key in cmd_dict]
    return cmd_list

#This allows a dictionary to be passed to each class in order to bulk update params
def updater(self, updated_dict):
    current_dict = vars(self)
    for key in updated_dict:
        ### just check they have a correct match
        if key in current_dict:
            setattr(self, key, updated_dict[key])
        else:
            print("WARNING", key, "SKIPPED AS NOT RECOGNISED" )
#Print output  
def printer(self):
    attrs = vars(self)
    try:
        from pprint import pprint
        out_dict = pprint(attrs)
    except:
        print(attrs)

# %% [markdown]
# ### Param Storage Classes

# %%
#Parent class that all parameter holding child classes inherit methods defined  
class _section:
    def print_all(self):
        printer(self)    
    def update(self, updated_dict):
        updater(self, updated_dict)    
    def gen_output(self):
        return gen_cmd_list(self)
    
#child classes: here they hold the user input for the run    
class _tables_sse(_section):
    ###set up inputs --------------------
    def __init__(self):
        self.LISTBIN = os.path.join(SEVN,"run_scripts","listStar.dat") #Complete path to input file (list of binaries or single stars)
        self.IBMODE="new" #Input file format for binaries [new*] [legacy] [sevn1]
        self.TABLES = os.path.join(SEVN,"tables","SEVNtracks_parsec_ov05_AGB") #Complete path to look-up tables
        self.TABLESHE = os.path.join(SEVN,"tables", "SEVNtracks_parsec_pureHe36") #Complete path to look-up tables for pure-He stars
        self.TEND="list"
        self.TSTART="list"
        self.RSEED="false"
        
class _tables_bin(_tables_sse):
    def __init__(self):
        super().__init__()
        self.LISTBIN=os.path.join(SEVN,"run_scripts", "listBin.dat")

class _output(_section):
    ###set up inputs --------------------
    def __init__(self):
        #defult can change it for the model if we want
        self.OUTPATH = os.path.join(SEVN,"sevn_output_py") #Complete path to the output folder (the folder will be automatically created or cleaned if it already exists)
        self.OMODE="csv" #Format for output files [h5] [ascii*] [csv]
        self.NAMEPREX=""  #prefix to add to the name of the systems
        self.LOGLEVEL="critical"  #Log output level: [debug] [info] [warning] [error] [critical]
        self.LITPHASES="false" #Use literal phases instead of numbers in output [true] - [false*]
        self.LOGFILE="true" #If true produce the logfile output  [true] - [false*]
        self.SCOL="Mass:MHE:MCO:Radius:Luminosity:Temperature:Phase:RemnantType" #Additional columns to print in the output file for single stellar evolution runs. Default is empty, but any property of single stars can be added (check names in the Property class)
        self.BCOL="Semimajor:Eccentricity:BEvent:BWorldtime" #Additional columns to print in the output file for binary stellar evolution runs. Default is empty, but any property of binary stars can be added (check names in the BinaryProperty class)
        self.RUNCMD = "Not ran yet"

class _prescriptions_sse(_section):
    ###set up inputs --------------------
    def __init__(self):
        self.SNKICKS="unified" #Prescriptions for SN kicks - [unified*] [hobbs] [hobbs_pure] [cc15] [ecus30] [ec15cc265] [zeros]
        self.SNPISN="mapelli20" #Prescription for pair instability SN - [mapelli20*] [iorio22] [iorio22_limited] [farmer19] [disabled]
        self.SNNML="lattimer89" #Prescription for neutrino mass loss in SN - [lattimer89*] [disabled]
        self.SUPERNOVA="list" #Prescription for the SN explosion mechanism - [list*] [rapid] [rapid_gauNS] [delayed] [delayed_gauNS] [compact] [deathmatrix] [directcollapse]
        self.BHXSPIN="disabled"
        
class _prescriptions_bin(_section):
    ###set up inputs --------------------
    def __init__(self):
        self.INDSMODE="hurley" #Prescriptions for wind accretion and the associated orbital changes - [hurley*] [disabled]
        self.TIDES="tides_simple" #Prescriptions for tides - [simple*] [disabled]
        self.GWMODE="peters" #Prescriptions for gravitational-wave decay - [peters*] [disabled]
        self.RLMODE="hurley_rl" #Prescriptions for Roche-Lobe overflow and mass transfer/accretion - [hurley_rl*] [hurley_bse] [disabled]
        self.CIRCMODE="periastron" #Prescriptions for orbit circularisation at onset of RLO - [periastron*] [periastron_full] [angmomg] [semimajor] [disabled]
        self.CEMODE="energy" #Prescriptions for common-envelope evolution - [energy*] [disabled]
        self.MIXING="simple" #Prescriptions  for mixing (merger) - [simple*] [disabled]
        self.COLLMODE="hurley" #Prescriptions for collision at periastron - [hurley*] [disabled]
        self.HARDMODE="disabled" #Prescriptions for hardening in stellar clusters [disabled*] [fastcluster]
        self.SNORBCHANGE="hurley" #Prescriptions for orbital changes after SN kicks - [hurley*] [disabled]
        self.SNKICKS="unified" #Prescriptions for SN kicks - [unified*] [hobbs] [hobbs_pure] [cc15] [ecus30] [ec15cc265] [zeros]
        self.SNPISN="mapelli20" #Prescription for pair instability SN - [mapelli20*] [iorio22] [iorio22_limited] [farmer19] [disabled]
        self.SNNML="lattimer89" #Prescription for neutrino mass loss in SN - [lattimer89*] [disabled]
        self.SUPERNOVA="list" #Prescription for the SN explosion mechanism - [list*] [rapid] [rapid_gauNS] [delayed] [delayed_gauNS] [compact] [deathmatrix] [directcollapse]
        self.BHXSPIN="disabled" #Prescription for the BH spin - [disabled*] [geneva] [mesa] [fuller] [maxwellian] [accretion]l columns to print in the output file for binary stellar evolution runs. Default is empty, but any property of binary stars can be added (check names in the BinaryProperty class)

class _options_sse(_section):
    ###set up inputs --------------------
    def __init__(self):
        self.TABCONV="true" #If true estimate the properties of the convective envelope using the tables (xxxconv.dat)
        self.TABXSUP="false"  #If true use the surface abundance tables (xxxsup.dat)
        self.TABINERTIA="false" #If true estimate the properties of the stellar inerita using the tables (inertia.dat)
        self.TABRHE="true" #If true estimate the properties of the HE core radius using the tables (rhe.dat)
        self.INERTIAMODE="Hurley" #option for inertia estimate when tabuse_inertia is false [*Hurley][DeMink][hspherecore][hsphere]
        self.TABRCO="true" #If true estimate the properties of the CO core radius using the tables (rhe.dat)
        self.THGHURLEY="false" #If true estimate the HG time from the Hurley+00 functional forms instead of using the convective envelope
        self.OPTIMISTIC="false" #If true allow the star in the HG (Hurley phase 2) to start a CE
        
class _options_bin(_section):
    ###set up inputs --------------------
    def __init__(self):
        self.SQHE="false" #If true enable the Quasi Homogeneous Evolution  after a RLO mass transfer following Elrdige&Stanway11
        self.TABCONV="true" #If true estimate the properties of the convective envelope using the tables (xxxconv.dat)
        self.TABXSUP="false"  #If true use the surface abundance tables (xxxsup.dat)
        self.TABINERTIA="false" #If true estimate the properties of the stellar inerita using the tables (inertia.dat)
        self.INERTIAMODE="Hurley" #option for inertia estimate when tabuse_inertia is false [*Hurley][DeMink][hspherecore][hsphere]
        self.TABRHE="true" #If true estimate the properties of the HE core radius using the tables (rhe.dat)
        self.TABRCO="true" #If true estimate the properties of the CO core radius using the tables (rhe.dat)
        self.THGHURLEY="false" #If true estimate the HG time from the Hurley+00 functional forms instead of using the convective envelope
        self.OPTIMISTIC="false" #If true allow the star in the HG (Hurley phase 2) to start a CE

class _params_sse(_section):
    def __init__(self):
        self.MCHANDRA="1.44" #Chandrasekar mass limit for WD formation
        self.SNLOWECSN="1.38" #Minimum value for the CO mass to go ECSN
        self.SNLOW="1.44" #Minimum CO value for the CO mass to go SN (i.e. max CO mass for ECSN)
        self.SNLOWECSNHE="-1"  #Minimum value for the CO mass to go ECSN for pureHe star, if -1 use the same value as H star
        self.SNLOWHE="-1" #Minimum CO value for the CO mass to go SN (i.e. max CO mass for ECSN) for pureHe star, if -1 use the same value as H star
        self.SNC25TS="0.35" #csi25 parameter threshold for explosion/implosion decision, if -1 use a stochastic threshold based on the results of  Patton&Sukhbold20
        self.SNCOMPFB="0.9" #Fallback fraction for implosions in the compact SN option
        self.SNMINVKICK="0.0" #Minimum SN Kick after all the corrections
        self.SNVKICKSTD="265.0" #Standard deviation  of the Maxwellian distribution of kick velocity (Used in the Hobbs and Unified SN kick model)
        #-------WINDS-------#
        self.WALPHA="1.5" #alpha factor to tune the amount of wind accretion (Eq.6 Hurley+02)
        self.WBETA="0.125" #beta factor to tune wind velocity (Eq.9 in Hurley+02)
        #-------CE-------#
        self.CELAM="-1" #if >0 Constant Lambda in binding energy (Eq. 69 in Hurley02). If -1 same Lambda as in BSE (-11 and -12 are other BSE-like variations).
        #-4 Lambda interpolated from Klencki21 (-41 is a variation in which the Lambda is not interpolated but it is "quantised" in bins)
        #-5 Lambda interpolated from  Xu&Li10  (-51 is a variation in which the Lambda is not interpolated but it is "quantised" in bins)
        self.CELAMHE="0.5" #Constant Lambda in binding energy used for pureHe stars(Eq. 69 in Hurley02).
        # Notice: some Lambda model have their own estimate of Lamdba_he (for example option -4), in this case this value is not considered
        self.CELAMFTH="1"  #Fraction of internal energy that goes to the binding energy. Used only if star_lambda<0. Notice that some Lambda models do not include an option for the fraction of internal energu (e.g. option -5)
        #-------NS-------#
        self.NSMAX="3.0" #Maximum NS mass
        self.NSMAGTSCALE="1000" #Magnetic field decay timescale in Myr
        self.NSMAGMSCALE="0.15" #Magnetic field decay mass-scale in Msun
        self.NSMASSMEAN="1.33" #NS masses are drawn from a Gaussian with this mean. Notice, not all the SNMODE options allows to use it
        self.NSMASSSTD="0.09" #NS masses are drawn from a Gaussian with this std. Notice, not all the SNMODE options allows to use it
        #-------BH-------#
        self.MAXWSDXSPIN="0.1" # Standard deviation of the Maxwellian distribution for Xspin - default: 0.1.
        self.BAVERAXSPIN="false" # Bavera correction for the black-hole spin - default: false.
        
class _params_bin(_section): #### paramter def
    def __init__(self):
        #-------GW-------#
        self.GWTSHOLD= "1" #Enable GW decay if GW_time_decay < GWTSHOLD*Hubble_time
        self.GWONLYBCO="false" #If true activate the GW orbital decay on for binary compact objects
        #-------RLO-------#
        self.RLOEPSNOVA="0.001" #Fraction of accreted matter retained in nova eruption
        self.RLOMACCR="0.5" #Fraction of the mass lost by the primary that is accreted onto the secondary during RLO
        self.RLOGAM="-2" #Angular momentum lost during RLO. [-1]: from the primary, [-2]: from the secondary, [>0]: fraction lost from the system
        self.RLOSTABILITY="qcrit_Hradiative_stable"  #"Option for RLO mass transfer stability
        self.RLONTMAX="5"    #Max value of the mass to use in the normalisation of the nuclear mass transfer (Eq. 59 Hurley+02)
        self.RLOCOLLISION="false"  #If true allow collision at periastron during RLO
        self.RLOSMTMS="true"   #If true mass transfer from radiative MS and pureHE MS are always stable
        #-------ACCRETION-------#
        self.EDDF="1" #Eddington factor to limit accretion on a compact object (>1 means super-Eddington)
        #-------SN-------#
        self.MCHANDRA="1.44" #Chandrasekar mass limit for WD formation
        self.SNLOWECSN="1.38" #Minimum value for the CO mass to go ECSN
        self.SNLOW="1.44" #Minimum CO value for the CO mass to go SN (i.e. max CO mass for ECSN)
        self.SNLOWECSNHE="-1"  #Minimum value for the CO mass to go ECSN for pureHe star, if -1 use the same value as H star
        self.SNLOWHE="-1" #Minimum CO value for the CO mass to go SN (i.e. max CO mass for ECSN) for pureHe star, if -1 use the same value as H star
        self.SNC25TS="0.35" #csi25 parameter threshold for explosion/implosion decision, if -1 use a stochastic threshold based on the results of  Patton&Sukhbold20
        self.SNCOMPFB="0.9" #Fallback fraction for implosions in the compact SN option
        self.SNMINVKICK="0.0" #Minimum SN Kick after all the corrections
        self.SNVKICKSTD="265.0" #Standard deviation  of the Maxwellian distribution of kick velocity (Used in the Hobbs and Unified SN kick model)
        #-------WINDS-------#
        self.WALPHA="1.5" #alpha factor to tune the amount of wind accretion (Eq.6 Hurley+02)
        self.WBETA="0.125" #beta factor to tune wind velocity (Eq.9 in Hurley+02)
        #-------CE-------#
        self.CEALPHA="3" #alpha in binding energy (Eq. 73 in Hurley02)
        self.CELAM="-1" #if >0 Constant Lambda in binding energy (Eq. 69 in Hurley02). If -1 same Lambda as in BSE (-11 and -12 are other BSE-like variations).
        #-4 Lambda interpolated from Klencki21 (-41 is a variation in which the Lambda is not interpolated but it is "quantised" in bins)
        #-5 Lambda interpolated from  Xu&Li10  (-51 is a variation in which the Lambda is not interpolated but it is "quantised" in bins)
        self.CELAMHE="0.5" #Constant Lambda in binding energy used for pureHe stars(Eq. 69 in Hurley02).
        # Notice: some Lambda model have their own estimate of Lamdba_he (for example option -4), in this case this value is not considered
        self.CELAMFTH="1"  #Fraction of internal energy that goes to the binding energy. Used only if star_lambda<0. Notice that some Lambda models do not include an option for the fraction of internal energu (e.g. option -5)
        self.CEKCE="1"  #Fraction of non core mass  participating to the CE (e.g. envelope of giants) retained after the CE coalescence.If -1, use a rescaled version of eq. 77 In Hurley
        self.CEKNCE="1" #Fraction of non core mass not participating to the CE (e.g. a MS star) retained after the CE coalescence.If -1, use the eq. 77 in Hurley 2002 (ce_kce is ignored)
        #-------Hardening-------#
        self.HARDRHOC="39900" #central density of the cluster in Msun/pc^3
        self.HARDSIGMA="5" #3D velocity dispersion of the cluster in km/s
        self.HARDXI="3" #xi parameter for fastcluster hardening option (Eq. 11 Mapelli+21)
        self.HARDKAPPA="0.1" #kappa parameter for fastcluster hardening option (Eq. 13 Mapelli+21)
        self.HARDMASS="1" #Average mass of the perturber stars in the environment producing the hardening in Msun
        #-------NS-------#
        self.NSMAX="3.0" #Maximum NS mass
        self.NSMAGTSCALE="1000" #Magnetic field decay timescale in Myr
        self.NSMAGMSCALE="0.15" #Magnetic field decay mass-scale in Msun
        self.NSMASSMEAN="1.33" #NS masses are drawn from a Gaussian with this mean. Notice, not all the SNMODE options allows to use it
        self.NSMASSSTD="0.09" #NS masses are drawn from a Gaussian with this std. Notice, not all the SNMODE options allows to use it
        #-------BH-------#
        self.MAXWSDXSPIN="0.1" # Standard deviation of the Maxwellian distribution for Xspin - default: 0.1.
        self.BAVERAXSPIN="false" # Bavera correction for the black-hole spin - default: false.
                
class _adv_params(_section): #### paramter def
    def __init__(self):
        #Parameters for jumping onto new tracks
        #-------------------------------
        self.JTEMAX="0.005" #Maximum relative error in mass when jumping on a new track
        self.JTMAXDM="1.2" #Maximum new ZAMS tested when jumping on a new track (Mzams_new_max = Mzams_old + JTMAXDM*DM_accreted_or_donated)
        self.JTMINDM="0" #Minimum new ZAMS tested when jumping on a new track (Mzams_new_min = Mzams_old + JTMINDM*DM_accreted_or_donated)
        self.JTMAXITER="10" #Maximum number of iterations for reaching convergence
        self.JTDMTSHOLD="0.01" #Maximum relative change in total mass for not changing track
        # -------------------------------
        #Other parameters
        #-------------------------------
        self.MAXREP="50" #Maximum number of repetitions allowed in the sse and bse. If we reach this number an error is raised
        self.NAKEDTS="1E-4" #Mass difference threshold (Msun) between envelope and core to set a star as nakedHe or nakedCO.
        self.WRTS="0.021" #Relative difference threshold between envelope (Mass-MHE) and total mass to define a star as Wolf Rayet
        self.INITERRSTOP="false" #If true terminate the run when a error on a system initialisation is thrown
        self.SMAXCO="false" #If true the first time a star develops a CO core, we set the maximum CO core Mass for SSE as the last value of the interpolating tracks
        self.SMINHE="false" #If true the first time a star develops a CO core, we set the minimum HE core Mass for SSE as the last value of the interpolating tracks
        # -------------------------------
        #Interpolation
        #-------------------------------
        self.INTW="linear" #Option for setting the weights in the Mass interpolation [*linear][rational][log], Notice for Radius, Inertia and Luminosity it set to log
        self.INTWLOG="log" #Option to set weights for mass interpolation for log properties (i.e. Radius,Luminosity,Inertia) [linear][rational][*log]
        self.INTWPHASE="rational" #Option to set weights for estimating the stellar phases times [linear][*rational][log]
        # -------------------------------
        #Timestep
        #-------------------------------
        self.TSMAXVAR="0.05"  #Relative maximum variation of stellar and binary properties used in the adaptive time step
        self.TSMIN="-1" #Force the adaptive timestep to be larger than this value, it will it has the priority on any other option, -1 means that the option is disabled
        self.TSMAX="-1" #Force the adaptive timestep to be smaller than this value, it has the priority on any other option, -1 means that the option is disabled
        self.TSSPIN="false" #If true take into account the variation (SSE only) of OmegaSpin in the adaptive timestep
        self.TSSPINBIN="false" #If true take into account the variation (BSE only) of OmegaSpin in the adaptive timestep
        self.TSNSSPIN="false" #If true take into account the variation of OmegaRem for NS in the adaptive timestep. It should be set to true if interested on pulsars
        self.CKSTALLING="true" #If true check stalling stars. If the elapsed evolution time is larger than 20s an error is thrown

# %% [markdown]
# ## Define Model Classes

# %%
class sse:       
    def __init__(self):
        if 'SEVN' not in globals():print(path_error)
        self.tables = _tables_sse()
        self.output = _output()
        self.prescriptions = _prescriptions_sse()
        self.options = _options_sse()# cant be smaller 
        self.params = _params_sse()
        self.adv_params = _adv_params()
        self.Z= "list"  #Stellar metallicity - [*list][number]. If list use the Z in the input file otherwise overwrite all the Zs.
        self.runbool= False # keep track if the model has been ran 
        self.EXE = os.path.join(SEVN, "build", "exe", "sevn.x")
        self.output.SCOL='Worldtime:Mass:MHE:MCO:Radius:Luminosity:Temperature:Phase:RemnantType'
        self.output.BCOL="Semimajor:Eccentricity:BEvent" 
        self.tables.LISTBIN = os.path.join(SEVN,"run_scripts","listStar.dat")
        
    def run(self, NTHREADS ="1", #Number of OpenMP threads (1 means no parallel threads, sequential execution)
            NCHUNK = "1000", #Evolve Nchunk at time
            DTOUT="list", #If list use the dtout reported in the input list, otherwise use this value for all the stars and binaries (Can be a number in Myr (e.g. 10), a colon separated sequence in Myr (e.g. 10:100:10 goes from 10 Myr to 10
            PRINTFILE =False): 

        run_dict = {'NTHREADS': str(NTHREADS), 'NCHUNK' : str(NCHUNK),  'DTOUT' : DTOUT}
        # concat the output lists
        F = gen_cmd_list(run_dict) + self.tables.gen_output() + self.output.gen_output() + self.prescriptions.gen_output()         + self.options.gen_output() + self.params.gen_output()+ self.adv_params.gen_output()         + ["Z "+str(self.Z)]
        
        final_cmd = self.EXE + " " + "-"+' -'.join(F)
        self.output.RUNCMD = final_cmd
        launch_time = datetime.now()

        if not os.path.isdir(self.output.OUTPATH):os.mkdir(self.output.OUTPATH)
        print_option = None
        #os.system("cd "+self.output.OUTPATH+"; "+final_cmd)#SEVN cleans folder automatically  
        from subprocess import run as sp_run, PIPE# more compatable than capture_output
        if PRINTFILE: print_option = PIPE
        print('running')
        sp=sp_run(final_cmd, stdout=print_option, stderr=print_option, shell=True, cwd=self.output.OUTPATH)

        if PRINTFILE: 
            run_output=sp.stdout
            run_error=sp.stderr
            if type(run_output)!=str: run_output=run_output.decode()
            if type(run_error)!=str: run_error=run_error.decode()
            print('RUN output saved to' + str(os.path.join(self.output.OUTPATH, 'run_output.txt')) )
            run_output_path = os.path.join(self.output.OUTPATH, 'run_output.txt')
            run_error_path = os.path.join(self.output.OUTPATH, 'err_output.txt')
            out_f = open(run_output_path, "w")
            out_f.write(run_output)
            out_f.close()
            out_f = open(run_error_path, "w")
            out_f.write(run_error)
            out_f.close()

        update_outdir(self, launch_time)
        self.runbool=True
        
    def output_df(self):
        if self.runbool:## will make smarter soon
            import pandas as pd ## on
            df = pd.read_csv(os.path.join(self.output.OUTPATH, 'output_0.csv'), sep=",")
            return df
        else:
            print("Must run first")
            
    ## this is pretty printed which makes it a string 
    def print_all(self):
        class_dict=vars(self)
        out_dict ={}
        for key in class_dict:
            if hasattr(class_dict[key], 'update'):
                out_dict[key] = vars(class_dict[key])
            if isinstance(class_dict[key], str):
                out_dict[key] = class_dict[key]            
        ### just to make the dictionary nice 
        try:
            from pprint import pprint
            out_dict = pprint(out_dict)
        except:
            print(out_dict)
                
    def get_dict(self):
        class_dict=vars(self)
        out_dict ={}
        for key in class_dict:
            if hasattr(class_dict[key], 'update'):
                out_dict[key] = vars(class_dict[key])
            if isinstance(class_dict[key], str):
                out_dict[key] = class_dict[key]
        return out_dict 
    
    #This method can both find and update the correct subclass attribute in order to be easier for users
    def update(self, updated_dict):## allows simple ways to update
        if isinstance(updated_dict, str):eval(updated_dict)# can update from pretty print
        updated_dict= dict(updated_dict)
        class_dict = vars(self)
        out_dict = {}

        for key in updated_dict:
            if key in class_dict: ##check if update and shared have same key is in class 
                if hasattr(class_dict[key], 'update'):# Checks if subclass
                    class_dict[key].update(updated_dict[key])
                
                #some attributes are keys some classes
                if isinstance(updated_dict[key], str):
                    setattr(self, key, updated_dict[key])
                
            for class_key in class_dict: ## loop all class elements
                if hasattr(class_dict[class_key], 'update'): # check if is subclass
                    subclass_dict= vars(class_dict[class_key])
                    if key in subclass_dict:## need a cleaner way to acesss subclass
                        eval_str = 'self'+"."+class_key+"."+key+" = "+'str(updated_dict[key])'
                        exec(eval_str)
                        #sub_class_attr= getattr(self, class_key)

class binary(sse):
    def __init__(self):
        if 'SEVN' not in globals():print(path_error)
        sse.__init__(self)
        self.tables = _tables_bin()
        self.output = _output()
        self.prescriptions = _prescriptions_bin()
        self.options = _options_bin()
        self.params = _params_bin()
        self.adv_params = _adv_params()
        self.Z= "list"  #Stellar metallicity - [*list][number]. If list use the Z in the input file otherwise overwrite all the Zs.
        self.runbool= False # keep track if the model has been ran 
        self.EXE = os.path.join(SEVN,"build","exe","sevnB.x")

# %% [markdown]
# ## Runing Models

# %% [markdown]
# #### Set SEVN Directory

# %%
set_path("/home/jake/SEVN/sevndevel")
check_compile()
# Out:
# SEVN already compiled

# %% [markdown]
# ###  Binary Model
# First create a class instance, all the default parameters are ready use

# %%
m=binary()

# %% [markdown]
# Users can to check the default parameters used so they can make changes if necessary, it's important to note that this can act as a map showing where the attributes are. As we can see below the class is divided into subclasses. We can print and update from the whole class or just inside each subsection.

# %%
m.print_all()
# Out:
# {'EXE': '/home/jake/SEVN/sevndevel/build/exe/sevnB.x',
#  'Z': 'list',
#  'adv_params': {'CKSTALLING': 'true',
#                 'INITERRSTOP': 'false',
#                 'INTW': 'linear',
#                 'INTWLOG': 'log',
#                 'INTWPHASE': 'rational',
#                 'JTDMTSHOLD': '0.01',
#                 'JTEMAX': '0.005',
#                 'JTMAXDM': '1.2',
#                 'JTMAXITER': '10',
#                 'JTMINDM': '0',
#                 'MAXREP': '50',
#                 'NAKEDTS': '1E-4',
#                 'SMAXCO': 'false',
#                 'SMINHE': 'false',
#                 'TSMAX': '-1',
#                 'TSMAXVAR': '0.05',
#                 'TSMIN': '-1',
#                 'TSNSSPIN': 'false',
#                 'TSSPIN': 'false',
#                 'TSSPINBIN': 'false',
#                 'WRTS': '0.021'},
#  'options': {'INERTIAMODE': 'Hurley',
#              'OPTIMISTIC': 'false',
#              'SQHE': 'false',
#              'TABCONV': 'true',
#              'TABINERTIA': 'false',
#              'TABRCO': 'true',
#              'TABRHE': 'true',
#              'TABXSUP': 'false',
#              'THGHURLEY': 'false'},
#  'output': {'BCOL': 'Semimajor:Eccentricity:BEvent:BWorldtime',
#             'LITPHASES': 'false',
#             'LOGFILE': 'true',
#             'LOGLEVEL': 'critical',
#             'NAMEPREX': '',
#             'OMODE': 'csv',
#             'OUTPATH': '/home/jake/SEVN/sevndevel/sevn_output_py',
#             'RUNCMD': 'Not ran yet',
#             'SCOL': 'Mass:MHE:MCO:Radius:Luminosity:Temperature:Phase:RemnantType'},
#  'params': {'BAVERAXSPIN': 'false',
#             'CEALPHA': '3',
#             'CEKCE': '1',
#             'CEKNCE': '1',
#             'CELAM': '-1',
#             'CELAMFTH': '1',
#             'CELAMHE': '0.5',
#             'EDDF': '1',
#             'GWONLYBCO': 'false',
#             'GWTSHOLD': '1',
#             'HARDKAPPA': '0.1',
#             'HARDMASS': '1',
#             'HARDRHOC': '39900',
#             'HARDSIGMA': '5',
#             'HARDXI': '3',
#             'MAXWSDXSPIN': '0.1',
#             'MCHANDRA': '1.44',
#             'NSMAGMSCALE': '0.15',
#             'NSMAGTSCALE': '1000',
#             'NSMASSMEAN': '1.33',
#             'NSMASSSTD': '0.09',
#             'NSMAX': '3.0',
#             'RLOCOLLISION': 'false',
#             'RLOEPSNOVA': '0.001',
#             'RLOGAM': '-2',
#             'RLOMACCR': '0.5',
#             'RLONTMAX': '5',
#             'RLOSMTMS': 'true',
#             'RLOSTABILITY': 'qcrit_Hradiative_stable',
#             'SNC25TS': '0.35',
#             'SNCOMPFB': '0.9',
#             'SNLOW': '1.44',
#             'SNLOWECSN': '1.38',
#             'SNLOWECSNHE': '-1',
#             'SNLOWHE': '-1',
#             'SNMINVKICK': '0.0',
#             'SNVKICKSTD': '265.0',
#             'WALPHA': '1.5',
#             'WBETA': '0.125'},
#  'prescriptions': {'BHXSPIN': 'disabled',
#                    'CEMODE': 'energy',
#                    'CIRCMODE': 'periastron',
#                    'COLLMODE': 'hurley',
#                    'GWMODE': 'peters',
#                    'HARDMODE': 'disabled',
#                    'INDSMODE': 'hurley',
#                    'MIXING': 'simple',
#                    'RLMODE': 'hurley_rl',
#                    'SNKICKS': 'unified',
#                    'SNNML': 'lattimer89',
#                    'SNORBCHANGE': 'hurley',
#                    'SNPISN': 'mapelli20',
#                    'SUPERNOVA': 'list',
#                    'TIDES': 'tides_simple'},
#  'tables': {'IBMODE': 'new',
#             'LISTBIN': '/home/jake/SEVN/sevndevel/run_scripts/listBin.dat',
#             'RSEED': 'false',
#             'TABLES': '/home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB',
#             'TABLESHE': '/home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36',
#             'TEND': 'list',
#             'TSTART': 'list'}}

# %% [markdown]
# Run the model

# %%
m.run(NTHREADS = 4,PRINTFILE=True) #printed version shown at the end of nb
# Out:
# running
# RUN output saved to/home/jake/SEVN/sevndevel/sevn_output_py/run_output.txt
# Directory '/home/jake/SEVN/sevndevel/sevn_output_py' created

# %% [markdown]
# The RUN command is stored in both a file like the original runscripts and as a python class attribute

# %%
m.output.RUNCMD
# Out:
# '/home/jake/SEVN/sevndevel/build/exe/sevnB.x -nthreads 4 -ev_Nchunk 1000 -dtout list -list /home/jake/SEVN/sevndevel/run_scripts/listBin.dat -ibmode new -tables /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB -tables_HE /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36 -tf list -tini list -rseed false -o /home/jake/SEVN/sevndevel/sevn_output_py -omode csv -log_level critical -io_literal_phases false -io_logfile true -scol Mass:MHE:MCO:Radius:Luminosity:Temperature:Phase:RemnantType -bcol Semimajor:Eccentricity:BEvent:BWorldtime -tmode tides_simple -gwmode peters -rlmode hurley_rl -circmode periastron -cemode energy -mixmode simple -collmode hurley -hardmode disabled -kmode hurley -sn_kicks unified -sn_pairinstability mapelli20 -sn_neutrinomaloss lattimer89 -snmode list -xspinmode disabled -rlo_QHE false -tabuse_envconv true -tabuse_Xsup false -tabuse_inertia false -inertiamode Hurley -tabuse_rhe true -tabuse_rco true -use_thg_hurley false -optimistic_scenario_hg false -gw_tshold 1 -gw_onlybco false -rlo_eps_nova 0.001 -rlo_f_mass_accreted 0.5 -rlo_gamma_angmom -2 -rlo_stability qcrit_Hradiative_stable -rlo_max_nuclearmt 5 -rlo_enable_collision false -rlo_mtstable_ms true -eddington_factor 1 -sn_Mchandra 1.44 -sn_co_lower_ecsn 1.38 -sn_co_lower_sn 1.44 -sn_co_lower_ecsn_pureHe -1 -sn_co_lower_sn_pureHe -1 -sn_compact_csi25_tshold 0.35 -sn_compact_fallback 0.9 -sn_min_vkick 0.0 -sn_kick_velocity_stdev 265.0 -w_alpha 1.5 -w_beta 0.125 -ce_alpha 3 -star_lambda -1 -star_lambda_pureHe 0.5 -star_lambda_fth 1 -ce_kce 1 -ce_knce 1 -hard_rhoc 39900 -hard_sigma 5 -hard_xi 3 -hard_kappa 0.1 -hard_mass_average 1 -sn_max_ns_mass 3.0 -ns_magnetic_tscale 1000 -ns_magnetic_mscale 0.15 -sn_Mremnant_average_NS 1.33 -sn_Mremnant_std_NS 0.09 -xspin_sigma_maxwell 0.1 -xspin_bavera false -jtrack_h_err_rel_max 0.005 -jtrack_max_dm_factor 1.2 -jtrack_min_dm_factor 0 -jtrack_max_iteration 10 -jtrack_tshold_dm_rel 0.01 -ev_max_repetitions 50 -ev_naked_tshold 1E-4 -star_tshold_WR_envelope 0.021 -initerror_stop false -ev_set_maxCO false -ev_set_minHE false -ev_setwM linear -ev_setwM_log log -ev_setwM_tphase rational -ts_maximum_variation 0.05 -ts_min_dt -1 -ts_max_dt -1 -ts_check_spin false -ts_check_spin_bin false -ts_check_NSspin false -check_stalling true -Z list'

# %% [markdown]
# Results

# %%
m.output_df()
# Out:
#      ID             name    Mass_0  MHE_0  MCO_0  Radius_0  Luminosity_0  \
# 0     0  682213722854863  49.98475    0.0    0.0  7.693180  3.590456e+05
# 1     0  682213722854863  49.89554    0.0    0.0  8.241800  3.770751e+05
# 2     0  682213722854863  49.82089    0.0    0.0  8.556141  3.941441e+05
# 3     0  682213722854863  49.72149    0.0    0.0  8.993310  4.180734e+05
# 4     0  682213722854863  49.62210    0.0    0.0  9.452815  4.434554e+05
# ..   ..              ...       ...    ...    ...       ...           ...
# 568   0  682213722854863  17.14577    0.0    0.0  0.000073  1.000000e-10
# 569   0  682213722854863  17.14579    0.0    0.0  0.000073  1.000000e-10
# 570   0  682213722854863  17.14581    0.0    0.0  0.000073  1.000000e-10
# 571   0  682213722854863  17.14581    0.0    0.0  0.000073  1.000000e-10
# 572   0  682213722854863  17.14581    0.0    0.0  0.000073  1.000000e-10
#
#      Temperature_0  Phase_0  RemnantType_0  ...     MCO_1  Radius_1  \
# 0        50940.240        1              0  ...  0.000000  3.036591
# 1        49822.150        1              0  ...  0.000000  3.087479
# 2        49442.610        1              0  ...  0.000000  3.126264
# 3        48941.800        1              0  ...  0.000000  3.172789
# 4        48446.060        1              0  ...  0.000000  3.198997
# ..             ...      ...            ...  ...       ...       ...
# 568       2139.485        7              6  ...  1.142866  5.785162
# 569       2139.484        7              6  ...  1.144841  6.089709
# 570       2139.483        7              6  ...  1.146820  6.411536
# 571       2139.481        7              6  ...  1.147345  6.500095
# 572       2139.481        7              6  ...  0.000000  0.006342
#
#      Luminosity_1  Temperature_1  Phase_1  RemnantType_1  Semimajor  \
# 0      6151.70200       29334.74        1              0   500.0000
# 1      6217.20500       29169.12        1              0   500.7430
# 2      6266.86500       29045.33        1              0   501.3666
# 3      6337.03300       28911.96        1              0   502.1987
# 4      6420.32200       28887.43        1              0   503.0336
# ..            ...            ...      ...            ...        ...
# 568   25243.03000       30248.52        6              0   238.3057
# 569   25304.95000       29500.52        6              0   238.3062
# 570   25367.02000       28768.21        6              0   238.3066
# 571   25383.55000       28576.22        6              0   238.3068
# 572      89.62534      223016.70        7              3   251.6654
#
#      Eccentricity  BEvent  BWorldtime
# 0        0.200000      -1    0.000000
# 1        0.200000      -1    0.397078
# 2        0.200000      -1    0.695339
# 3        0.200000      -1    1.092418
# 4        0.199999      -1    1.489496
# ..            ...     ...         ...
# 568      0.000000      -1   24.667510
# 569      0.000000      -1   24.667880
# 570      0.000000      -1   24.668240
# 571      0.000000      -1   24.668340
# 572      0.053081       0   24.668340
#
# [573 rows x 22 columns]

# %% [markdown]
# ## Making changes to class attributes
#
# Two ways
# 1. Update with dictionary which is faster for large amounts of changes
# 2. Set class atribute directly ie m.params.HARDRHOC = value

# %%
##takes dictionary 
m.params.update({'HARDRHOC': 39970, 'HARDSIGMA' :4 , "bad key" : 'test'})
m.params.print_all()
# Out:
# WARNING bad key SKIPPED AS NOT RECOGNISED
# {'BAVERAXSPIN': 'false',
#  'CEALPHA': '3',
#  'CEKCE': '1',
#  'CEKNCE': '1',
#  'CELAM': '-1',
#  'CELAMFTH': '1',
#  'CELAMHE': '0.5',
#  'EDDF': '1',
#  'GWONLYBCO': 'false',
#  'GWTSHOLD': '1',
#  'HARDKAPPA': '0.1',
#  'HARDMASS': '1',
#  'HARDRHOC': 39970,
#  'HARDSIGMA': 4,
#  'HARDXI': '3',
#  'MAXWSDXSPIN': '0.1',
#  'MCHANDRA': '1.44',
#  'NSMAGMSCALE': '0.15',
#  'NSMAGTSCALE': '1000',
#  'NSMASSMEAN': '1.33',
#  'NSMASSSTD': '0.09',
#  'NSMAX': '3.0',
#  'RLOCOLLISION': 'false',
#  'RLOEPSNOVA': '0.001',
#  'RLOGAM': '-2',
#  'RLOMACCR': '0.5',
#  'RLONTMAX': '5',
#  'RLOSMTMS': 'true',
#  'RLOSTABILITY': 'qcrit_Hradiative_stable',
#  'SNC25TS': '0.35',
#  'SNCOMPFB': '0.9',
#  'SNLOW': '1.44',
#  'SNLOWECSN': '1.38',
#  'SNLOWECSNHE': '-1',
#  'SNLOWHE': '-1',
#  'SNMINVKICK': '0.0',
#  'SNVKICKSTD': '265.0',
#  'WALPHA': '1.5',
#  'WBETA': '0.125'}

# %%
## Alternatively
print("\n Return values")
m.params.HARDRHOC = 39900
m.params.HARDSIGMA = 5
m.params.print_all()
# Out:
#  Return values
# {'BAVERAXSPIN': 'false',
#  'CEALPHA': '3',
#  'CEKCE': '1',
#  'CEKNCE': '1',
#  'CELAM': '-1',
#  'CELAMFTH': '1',
#  'CELAMHE': '0.5',
#  'EDDF': '1',
#  'GWONLYBCO': 'false',
#  'GWTSHOLD': '1',
#  'HARDKAPPA': '0.1',
#  'HARDMASS': '1',
#  'HARDRHOC': 39900,
#  'HARDSIGMA': 5,
#  'HARDXI': '3',
#  'MAXWSDXSPIN': '0.1',
#  'MCHANDRA': '1.44',
#  'NSMAGMSCALE': '0.15',
#  'NSMAGTSCALE': '1000',
#  'NSMASSMEAN': '1.33',
#  'NSMASSSTD': '0.09',
#  'NSMAX': '3.0',
#  'RLOCOLLISION': 'false',
#  'RLOEPSNOVA': '0.001',
#  'RLOGAM': '-2',
#  'RLOMACCR': '0.5',
#  'RLONTMAX': '5',
#  'RLOSMTMS': 'true',
#  'RLOSTABILITY': 'qcrit_Hradiative_stable',
#  'SNC25TS': '0.35',
#  'SNCOMPFB': '0.9',
#  'SNLOW': '1.44',
#  'SNLOWECSN': '1.38',
#  'SNLOWECSNHE': '-1',
#  'SNLOWHE': '-1',
#  'SNMINVKICK': '0.0',
#  'SNVKICKSTD': '265.0',
#  'WALPHA': '1.5',
#  'WBETA': '0.125'}

# %% [markdown]
# ###  Single Stellar Evolution Model

# %%
sse_m = sse()
sse_m.params.print_all()
# Out:
# {'BAVERAXSPIN': 'false',
#  'CELAM': '-1',
#  'CELAMFTH': '1',
#  'CELAMHE': '0.5',
#  'MAXWSDXSPIN': '0.1',
#  'MCHANDRA': '1.44',
#  'NSMAGMSCALE': '0.15',
#  'NSMAGTSCALE': '1000',
#  'NSMASSMEAN': '1.33',
#  'NSMASSSTD': '0.09',
#  'NSMAX': '3.0',
#  'SNC25TS': '0.35',
#  'SNCOMPFB': '0.9',
#  'SNLOW': '1.44',
#  'SNLOWECSN': '1.38',
#  'SNLOWECSNHE': '-1',
#  'SNLOWHE': '-1',
#  'SNMINVKICK': '0.0',
#  'SNVKICKSTD': '265.0',
#  'WALPHA': '1.5',
#  'WBETA': '0.125'}

# %%
sse_m.run(NTHREADS="4", PRINTFILE= True)
# Out:
# running
# RUN output saved to/home/jake/SEVN/sevndevel/sevn_output_py/run_output.txt
# Directory '/home/jake/SEVN/sevndevel/sevn_output_py' created

# %%
sse_m.output_df()
# Out:
#      ID             name  Worldtime      Mass       MHE       MCO  \
# 0     0  791436360698323   0.000000  49.98475   0.00000   0.00000
# 1     0  791436360698323   0.397078  49.89554   0.00000   0.00000
# 2     0  791436360698323   0.695339  49.82089   0.00000   0.00000
# 3     0  791436360698323   1.092418  49.72149   0.00000   0.00000
# 4     0  791436360698323   1.489496  49.62210   0.00000   0.00000
# ..   ..              ...        ...       ...       ...       ...
# 363   0  791436360698323   4.298696  42.94083  23.93748  19.87889
# 364   0  791436360698323   4.298932  42.93776  23.93882  19.87889
# 365   0  791436360698323   4.299209  42.93415  23.94039  19.87889
# 366   0  791436360698323   4.299545  42.93001  23.94139  19.87889
# 367   0  791436360698323   4.299545  42.43001   0.00000   0.00000
#
#           Radius    Luminosity  Temperature  Phase  RemnantType
# 0       7.693180  3.590456e+05    50940.240      1            0
# 1       8.241800  3.770751e+05    49822.150      1            0
# 2       8.556141  3.941441e+05    49442.610      1            0
# 3       8.993310  4.180734e+05    48941.800      1            0
# 4       9.452815  4.434554e+05    48446.060      1            0
# ..           ...           ...          ...    ...          ...
# 363  1091.988000  7.967561e+05     5218.539      6            0
# 364  1092.724000  7.863159e+05     5199.608      6            0
# 365  1093.586000  7.742586e+05     5177.517      6            0
# 366  1122.972000  7.894528e+05     5134.211      6            0
# 367     0.000180  1.000000e-10     1360.038      7            6
#
# [368 rows x 11 columns]

# %% [markdown]
# ### Extra Functions

# %%
def clear_files(path):#semi redundent as sevn clears folders automatically 
    existing_files=os.listdir(path)
    for item in existing_files:
        item_path = os.path.join(path,item)
        if os.path.exists(item_path) and os.path.isdir(item_path)==False:
            os.remove(item_path)
            
clear_files(m.output.OUTPATH)

# %% [markdown]
# ### Run with print outs in cell

# %%
m.run(NTHREADS = 4) #printed version shown at the end of nb
# Out:
# running
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/003
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0008
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/001
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/005
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/002
#  inspectig dir = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00001/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/00005/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0001/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0002/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0004/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0006/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0008/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/001/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0014/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/0017/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/002/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/003/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB/004/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00001/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00002/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/00005/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0001/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0002/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/radius.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/time.dat
#  Found and opened
#  read the tables
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/csup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/depthconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/hesup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/hsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/inertia.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/nsup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/osup.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/qconv.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/rco.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/rhe.dat
#  Found and opened
#  Search optional file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0004/tconv.dat
#  Found and opened
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0008/lumi.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0008/mass.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0008/mco.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0008/mhe.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0008/phase.dat
#  Found and opened
#  read the tables
#  Search required file tables = /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36/0008/radius.dat
#  Found and opened
#  read the tables
# ...
# jtrack_max_iteration:              10                                 //[N][PS] Maximum, number of iteration to found the convergence
# jtrack_min_dm_factor:              0                                  //[N][PS] The minimum new zams that will be tested is Mzams +  jtrack_DM_factor_min*dM_accumul
# jtrack_tshold_dm_rel:              0.01                               //[N][PS] relative accumulated mass threshold to change tracks
# max_z:                             0.04                               //[N][NS] Max Z Mass in the loaded tables
# max_z_he:                          0.05                               //[N][NS] Max Z Mass in the loaded  pureHE tables
# max_zams:                          450                                //[N][NS] Max Zams Mass in the loaded tables
# max_zams_he:                       350                                //[N][NS] Max Zams Mass in the loaded pureHE tables
# min_z:                             0.0001                             //[N][NS] Min Z Mass in the loaded tables
# min_z_he:                          0.0001                             //[N][NS] Min Z Mass in the loaded pureHE tables
# min_zams:                          2                                  //[N][NS] Min Zams Mass in the loaded tables
# min_zams_he:                       0.36                               //[N][NS] Min Zams Mass in the loaded pureHE tables
# ns_magnetic_mscale:                0.15                               //[N][PS] Magnetic field decay mass-scale in Msun
# ns_magnetic_tscale:                1000                               //[N][PS] Magnetic field decay timescale in Myr
# ntest:                             -9                                 //[N][NS] Num param used only for tests
# nthreads:                          4                                  //[N][PS] Number of threads to be used
# rlo_eps_nova:                      0.001                              //[N][PS] Fraction of accreted matter retained in nova eruption
# rlo_f_mass_accreted:               0.5                                //[N][PS] Fraction of mass lost trough the  RLO that is accreted on the other star
# rlo_gamma_angmom:                  -2                                 //[N][PS] Parameter to manage the ang mom loss in hurley_rlo, if -1 angmom is lost from the primary (Jeans mode), -2 angmom is lost from the secondary (re-isotropic emission),otherwise if>0 gamma is the fraction of ang mom lost from the system.
# rlo_max_nuclearmt:                 5                                  //[N][PS] Max value of the mass to use in the normalisation of the nuclear mass transfer (Eq. 59 Hurley+02)
# sn_Mchandra:                       1.44                               //[N][PS] Chandrasekar mass limit for WD
# sn_Mejected_average:               -1                                 //[N][PS] Average remnant mass to use in the Unified kick model.  -1 use the default SN model value (if any)
# sn_Mremnant_average:               -1                                 //[N][PS] Average ejected mass to use in the Unified kick model. -1 use the default SN model value (if any)
# sn_Mremnant_average_NS:            1.33                               //[N][PS] Mean value of the Gaussian sampling the remnant mass for NS. Notice it is not used in all SNmodel. If SN model is compact this value overwrite the parameter is used also as sn_Mremnant_average.
# sn_Mremnant_std_NS:                0.09                               //[N][PS] Std value of the Gaussian sampling the remnant mass for NS. Notice it is not used in all SNmodel
# sn_co_lower_ecsn:                  1.38                               //[N][PS] Minimum value of the CO core  Mass  to explode as electron capture SN
# sn_co_lower_ecsn_pureHe:           -1                                 //[N][PS] Minimum value of the CO core  Mass  to explode as electron capture SN for pureHe star, if -1 use the same of H star
# sn_co_lower_sn:                    1.44                               //[N][PS] Minimum value of the CO core  Mass  to explode as SN
# sn_co_lower_sn_pureHe:             -1                                 //[N][PS] Minimum value of the CO core  Mass  to explode as SN for pureHe star, if -1 use the same of H star
# sn_compact_csi25_tshold:           0.35                               //[N][PS] csi25 parameter threshold for explosion/implosion decision, if -1 use a stochastic threshold based on the results of  Patton&Sukhbold20
# sn_compact_fallback:               0.9                                //[N][PS] Fallback fraction for implosions in the compact SN option
# sn_kick_velocity_stdev:            265                                //[N][PS] Standard deviation  of the Maxwellian distribution of kick velocity (Used in the Hobbs and Unified SN kick model)
# sn_max_ns_mass:                    3                                  //[N][PS] Maximum mass allowed for a NS
# sn_min_vkick:                      0                                  //[N][PS] Minimum Vkick after a SN explotsion in km/s
# star_lambda:                       -1                                 //[N][PS] if >0 Constant Lambda in binding energy (Eq. 69 in Hurley02). If -1 use Lambda from Claeys et al. 2014 (Appendix A).
# star_lambda_fth:                   1                                  //[N][PS] Fraction of internal energy that goes to the binding energy. Used only if star_lambda<0. Notice that some Lambda models do not include an option for the fraction of internal energu (e.g. option -5)
# star_lambda_pureHe:                0.5                                //[N][PS] Constant lambda to use for the pureHe stars. Notice: some Lambda model have their own estimate of Lamdba_he (for example option -4), in this case this value is not considered
# star_tshold_WR_envelope:           0.021                              //[N][PS] Relative difference threshold between envelope (Mass-MHE) and total mass to define a star as Wolf Rayet
# ts_max_dt:                         -1                                 //[N][PS] Force the adaptive timestep to be smaller than this value, it has the priority on any other option, -1 means that the option is disabled
# ts_maximum_variation:              0.05                               //[N][PS] Relative maximum variation of stellar and binary properties used in the adaptive time step
# ts_min_dt:                         -1                                 //[N][PS] Force the adaptive timestep to be larger than this value, it will it has the priority on any other option, -1 means that the option is disabled
# ts_min_points_per_phase:           10                                 //[N][PS] Set the maximum time step so that we have at least N points evaluated in each phase
# w_alpha:                           1.5                                //[N][PS] factor to tune mass accretion through winds (Eq.6 Hurley+02)
# w_beta:                            0.125                              //[N][PS] factor to tune stellar wind velocity (Eq.9 in Hurley+02)
# xspin_sigma_maxwell:               0.1                                //[N][PS] options for standard deviation of Maxwellian distribution for Xspin
# Z:                                 list                               //[L][PS] if list use the Z in the input list, otherwise ust this option for all the stars.
# bcol:                              Semimajor:Eccentricity:BEvent:BWorldtime//[L][PS] Additional columns to print in the output file for binary evolution runs. Default is empty, but any property of binary stars can be added (check names in the Property class)
# cemode:                            energy                             //[L][PS] Option for Common Envelope Process
# circmode:                          periastron                         //[L][PS] Option for orbit circularisation at the onset of RLO
# collmode:                          hurley                             //[L][PS] Option for stellar collision at periastron
# dtout:                             list                               //[L][PS] If list use the dtout reported in the input list, otherwise use this value for all the stars and binaries.
# ev_setwM:                          linear                             //[L][PS] Option to set weights for mass interpolation
# ev_setwM_log:                      log                                //[L][PS] Option to set weights for mass interpolation for log properties (i.e. Radius,Luminosity,Inertia)
# ev_setwM_tphase:                   rational                           //[L][PS] Option to set weights for estimating the stellar phases times
# gwmode:                            peters                             //[L][PS] Option for GW decay  Process
# hardmode:                          disabled                           //[L][PS] Option for hardening in clusters
# ibmode:                            new                                //[L][PS] Input file format for binaries [new*] [legacy] [sevn1]
# inertiamode:                       Hurley                             //[L][PS] option for inertia estimate when tabuse_inertia is false
# kmode:                             hurley                             //[L][PS] Option for SN kick Process
# list:                              /home/jake/SEVN/sevndevel/run_scripts/listBin.dat//[L][PS] Complete path to input file (list of binaries or single stars)
# log_level:                         critical                           //[L][PS] Log output level: debug, info, warning, error
# mixmode:                           simple                             //[L][PS] Option for stellar mix Process
# myself:                            /home/jake/SEVN/sevndevel/         //[L][NS] Complete path to the SEVN folder
# name_prefix:                                                          //[L][PS] prefix to add to the name of the systems
# o:                                 /home/jake/SEVN/sevndevel/sevn_output_py//[L][PS] Complete path to the output folder. It will be created by the code
# omode:                             csv                                //[L][PS] Define the results output format (ascii or csv)
# rlmode:                            hurley_rl                          //[L][PS] Option for Roche Lobe mass transfer Process
# rlo_stability:                     qcrit_Hradiative_stable            //[L][PS] Option for RLO mass transfer stability
# scol:                              Mass:MHE:MCO:Radius:Luminosity:Temperature:Phase:RemnantType//[L][PS] Additional columns to print in the output file for single evolution runs. Default is empty, but any property of single stars can be added (check names in the Property class)
# sn_kicks:                          unified                            //[L][PS] SN kick model
# sn_neutrinomloss:                  lattimer89                         //[L][PS] SN neutrino mass loss model
# sn_pairinstability:                mapelli20                          //[L][PS] SN pair instability model
# snmode:                            list                               //[L][PS] if list use the snmode in input, otherwise ust this option for all the stars.
# spin:                              list                               //[L][PS] if list use the spin in the input list, otherwise ust this option for all the stars.
# stest:                             test                               //[L][NS] Str param used only for tests
# tables:                            /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_ov05_AGB//[L][PS] Complete path to look-up tables
# tables_HE:                         /home/jake/SEVN/sevndevel/tables/SEVNtracks_parsec_pureHe36//[L][PS] Complete path to look-up tables of pure-HE stars
# tf:                                list                               //[L][PS] If list use the tf reported in the input list, otherwise use this value for all the stars and binaries.
# tini:                              list                               //[L][PS] If list use the tini reported in the input list, otherwise use this value for all the stars.
# tmode:                             tides_simple                       //[L][PS] Option for Tides  Process
# wmode:                             hurley_wind                        //[L][PS] Option for Wind mass transfer Process
# xspinmode:                         disabled                           //[L][PS] options for black hole spin models
# btest:                             true                               //[B][NS] Boolean param used only for tests
# check_stalling:                    true                               //[B][PS] If true check stalling stars. If the elapsed evolution time is larger than 20s an error is thrown
# ev_set_maxCO:                      false                              //[B][PS] If true the first time a star develops a CO core, we set the maximum CO core Mass for SSE as the last value of the interpolating tracks
# ev_set_minHE:                      false                              //[B][PS] If true the first time a star develops a CO core, we set the minimum HE core Mass for SSE as the last value of the interpolating tracks
# gw_onlybco:                        false                              //[B][PS] If true activate the GW orbital decay on for binary compact objects
# initerror_stop:                    false                              //[B][PS] If true terminate the run when a error on a system initialisation is thrown
# io_literal_phases:                 false                              //[B][PS] If true print the phase as literal otherwise as integer
# io_logfile:                        true                               //[B][PS] If true output the logfile
# optimistic_scenario_hg:            false                              //[B][PS] If true enable optimistic scenario for HG, i.e. allow to start a CE after a unstable mass transfer
# rlo_QHE:                           false                              //[B][PS] If true enable the Quasi Homogeneous Evolution  after a RLO mass transfer following Elrdige&Stanway11
# rlo_enable_collision:              false                              //[B][PS] If true allow collision at periastron during RLO
# rlo_mtstable_ms:                   true                               //[B][PS] If true mass transfer from radiative MS and pureHE MS are always stable
# rseed:                             false                              //[B][PS] If true the random seed is given in input in the source list (last column)
# tabuse_Xsup:                       false                              //[B][PS] If true use the surface abundance tables (xxxsup.dat, optional tables)
# tabuse_envconv:                    true                               //[B][PS] If true estimate the properties of the convective envelope using the tables (xxxconv.dat, optional tables)
# tabuse_inertia:                    false                              //[B][PS] If true use the inertia from tables (if present)
# tabuse_rco:                        true                               //[B][PS] If true interpolate RCO from tables (if present)
# tabuse_rhe:                        true                               //[B][PS] If true interpolate RHE from tables (if present)
# ts_check_NSspin:                   false                              //[B][PS] If true take into account the variation of OmegaRem for NS in the adaptive timestep. It should be set to true if interested on pulsars
# ts_check_spin:                     false                              //[B][PS] If true take into account the variation (SSE only) of OmegaSpin in the adaptive timestep
# ts_check_spin_bse:                 false                              //[B][PS] If true take into account the variation (BSE only) of OmegaSpin in the adaptive timestep
# use_thg_hurley:                    false                              //[B][PS] If true estimate the HG time from the Hurley+00 functional forms instead of using the convective envelope
# xspin_bavera:                      false                              //[B][PS] If true the Bavera correction for the black-hole spin is applied
# Directory '/home/jake/SEVN/sevndevel/sevn_output_py' created
